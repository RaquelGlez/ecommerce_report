# %% [markdown]
# # Análisis de Clientes y Comportamiento de Compras en un Ecommerce de México

# %% [markdown]
# Este proyecto presenta un ejercicio de análisis exploratorio de datos aplicado a un escenario de e-commerce, utilizando un dataset generado de forma sintética para simular la operación de una plataforma que opera en México.
#
# Aunque los datos fueron creados desde cero, la estructura del dataset está inspirada en el esquema del ecommerce brasileño Olist, ampliamente utilizado en ejercicios de análisis de datos. Esto permite trabajar con un modelo realista y completo, manteniendo un entorno controlado para la práctica y exploración.
#
# El objetivo principal del análisis es explorar el desempeño del proceso logístico y su relación con la satisfacción del cliente, a partir de métricas como los tiempos de entrega, el cumplimiento de las fechas prometidas y las calificaciones otorgadas por los compradores. El enfoque es completamente exploratorio, priorizando la identificación de patrones, comparaciones descriptivas y visualizaciones claras, sin recurrir a modelos predictivos avanzados.
#
# Este ejercicio se desarrolló previamente utilizando Excel y Power Query como una primera aproximación al análisis.
# La versión en Python busca extender ese trabajo, replicando y estructurando el proceso dentro de un flujo de análisis más modular y reproducible, organizado en notebooks por etapa.
#
# A lo largo del proyecto se recorren distintas fases, que van desde la preparación de los datos y la construcción de variables derivadas, hasta análisis descriptivos, exploraciones específicas y una lectura final desde una perspectiva de negocio.

# %% [markdown]
# A continuación, el proyecto se presenta dividido en varios notebooks, cada uno enfocado en una etapa específica del análisis. Esta estructura permite seguir el proceso de forma ordenada, desde la preparación de los datos hasta la obtención de insights descriptivos, y facilita la consulta individual de cada fase del trabajo.

# %% [markdown]
# Notebook 01 — Preparación de datos
#
# 📎 [Abrir en Google Colab](https://colab.research.google.com/github/RaquelGlez/ecommerce_report/blob/main/notebooks/01_data_preparation.ipynb)
#
# En este primer notebook se realiza la carga, revisión y limpieza inicial de los datasets que sirven como base para el proyecto.
# El objetivo es asegurar que la información esté en un estado coherente y adecuado para el análisis exploratorio antes de avanzar a etapas posteriores.
#
# Se inspeccionan estructuras, se revisan valores faltantes y se documentan decisiones clave de limpieza, manteniendo siempre un enfoque conservador.
# El resultado son datasets consistentes y reutilizables para el resto del análisis.

# %% [markdown]
# Notebook 02 — Feature Engineering
#
# 📎 [Abrir en Google Colab](https://colab.research.google.com/github/RaquelGlez/ecommerce_report/blob/main/notebooks/02_feature_engineering.ipynb)
#
# A partir de los datos limpios, este notebook se enfoca en la construcción de nuevas variables que facilitan el análisis.
# Se generan métricas relacionadas con tiempos de entrega, diferencias frente a fechas estimadas y valores monetarios de los pedidos.
#
# Las transformaciones se validan de forma básica para asegurar coherencia, dando como resultado un dataset enriquecido listo para exploración.

# %% [markdown]
# Notebook 03 — Exploratory Analysis
#
# 📎 [Abrir en Google Colab](https://colab.research.google.com/github/RaquelGlez/ecommerce_report/blob/main/notebooks/03_exploratory_analysis.ipynb)
#
# En este notebook se realiza un análisis exploratorio general para entender el comportamiento de los pedidos y sus métricas principales.
# Se analizan distribuciones y comparaciones básicas de volumen, tiempos de entrega y valores de compra.
#
# Este análisis sirve como punto de partida para identificar patrones generales y orientar exploraciones más específicas en los notebooks siguientes.

# %% [markdown]
# Notebook 04 — Logística y satisfacción del cliente
#
# 📎 [Abrir en Google Colab](https://colab.research.google.com/github/RaquelGlez/ecommerce_report/blob/main/notebooks/04_logistics_vs_satisfaction.ipynb)
#
# Aquí se explora la relación entre aspectos del proceso de entrega (tiempos, variación frente a la fecha estimada) y la satisfacción del cliente medida a través del review_score.
#
# Los resultados muestran que, en este dataset, no se observan relaciones claras entre logística y calificación, lo cual permite descartar asociaciones evidentes y refuerza el carácter exploratorio del proyecto.

# %% [markdown]
# Notebook 05 — Análisis geoespacial
#
# 📎 [Abrir en Google Colab](https://colab.research.google.com/github/RaquelGlez/ecommerce_report/blob/main/notebooks/05_geospatial_analysis.ipynb)
#
# Este notebook incorpora una dimensión regional al análisis, comparando métricas clave entre distintos estados.
# Debido a la naturaleza de los datos de geolocalización, el enfoque es comparativo y descriptivo, priorizando tablas resumen y rankings por estado.
#
# El análisis aporta una primera lectura territorial que complementa los notebooks anteriores.

# %% [markdown]
# Notebook 06 — Business Insights
#
# 📎 [Abrir en Google Colab](https://colab.research.google.com/github/RaquelGlez/ecommerce_report/blob/main/notebooks/06_business_insights.ipynb)
#
# El proyecto cierra con una exploración desde la perspectiva de negocio, analizando categorías de productos y vendedores.
# Se observan distribuciones de volumen, ingresos y participación, sin concentraciones extremas, lo cual es consistente con el carácter sintético del dataset.
#
# Este notebook sintetiza el análisis exploratorio desde un punto de vista más cercano a negocio y completa el recorrido del proyecto.

# %% [markdown]
# En conjunto, este proyecto se plantea como un ejercicio de análisis exploratorio, orientado a comprender los datos y extraer observaciones generales sobre su comportamiento.
# Las visualizaciones y hallazgos presentados tienen un propósito descriptivo y formativo, más que el de definir decisiones operativas concretas.
